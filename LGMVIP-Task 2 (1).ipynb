# %%
LGMVIP- Data Science Intern

# %%
Intermediate Level Task

# %%
By - Simantini Bhosale

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
import warnings
warnings.filterwarnings(action='ignore')
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, plot_confusion_matrix,accuracy_score
from sklearn.tree import plot_tree

# %%
dataset= pd.read_csv("iris.csv")

# %%
dataset.shape
# Out:
# (150, 6)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dataset.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
dataset.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.countplot(data=dataset, x='Species', palette='flare')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize':(8,6)})
sns.scatterplot(data=dataset, x='SepalLengthCm', y='SepalWidthCm',hue='Species', palette="Set2")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.distplot(x=dataset["PetalWidthCm"], kde=True, color='red');

# %%
sns.distplot(x=dataset["PetalLengthCm"], kde=True, color='black');

# %%
sns.pairplot(dataset, hue='Species',palette="husl");

# %%
X=dataset.drop(['Species'], axis=1)
y=dataset['Species']

X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
model=DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(figsize=(6,8), dpi=150)
plot_tree(model, filled= True, feature_names=X.columns, class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']);

# %%
#best pram method
model=DecisionTreeClassifier(max_depth= 4, max_leaf_nodes= 4, min_samples_split= 2)

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=4)

# %%
pred=model.predict(X_test)

# %%
print("Accuracy of model: ", accuracy_score(y_test,pred))
# Out:
# Accuracy of model:  1.0

# %%
plt.figure(figsize=(6,8), dpi=120)
plot_tree(model, filled= True, feature_names=X.columns, class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']);
